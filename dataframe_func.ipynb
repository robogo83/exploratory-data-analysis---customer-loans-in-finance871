# %%
# import libraries
import pandas as pd

# %%
# function for loading data in csv format and returning pandas dataframe
def csv_dataframe(csv_file):
    df = pd.read_csv(csv_file)
    return df

# %%
# creating the dataframe
loand_df = csv_dataframe('loan_payments.csv')

# %%
loan_df.shape
# Out:
# (54231, 44)

# %%
# display all the columns
pd.set_option('display.max_columns', None)
# data sample
loan_df.head()
# Out:
#    Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0           0  38676116   41461848         8000         8000.0
# 1           1  38656203   41440010        13200        13200.0
# 2           2  38656154   41439961        16000        16000.0
# 3           3  38656128   41439934        15000        15000.0
# 4           4  38656121   41439927        15000        15000.0
#
#    funded_amount_inv       term  int_rate  instalment grade sub_grade  \
# 0             8000.0  36 months      7.49      248.82     A        A4
# 1            13200.0  36 months      6.99      407.52     A        A3
# 2            16000.0  36 months      7.49      497.63     A        A4
# 3            15000.0  36 months     14.31      514.93     C        C4
# 4            15000.0  36 months      6.03      456.54     A        A1
#
#   employment_length home_ownership  annual_inc verification_status issue_date  \
# 0           5 years       MORTGAGE     46000.0        Not Verified   Jan-2021
# ...

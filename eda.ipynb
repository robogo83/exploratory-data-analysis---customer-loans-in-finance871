# %%
# Importing libraries and modules
from data_info import DataFrameInfo, DataFrameTransform, Plotter
import pandas as pd

# %%
# function for loading data in csv format and returning pandas dataframe
def csv_dataframe(csv_file):
    df = pd.read_csv(csv_file)
    return df

# %%
# creating the dataframe
loan_df = csv_dataframe('loan_payments.csv')
# creating two instances of two classes in data_info module
loan_info = DataFrameInfo(loan_df)
loan_tf = DataFrameTransform(loan_df)

# %% [markdown]
# ## Columns conversion

# %%
# stripping months and converting term column values into numeric ones
loan_tf.term_column_type('term', 'months')
# Out:
#        Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0               0  38676116   41461848         8000         8000.0
# 1               1  38656203   41440010        13200        13200.0
# 2               2  38656154   41439961        16000        16000.0
# 3               3  38656128   41439934        15000        15000.0
# 4               4  38656121   41439927        15000        15000.0
# ...           ...       ...        ...          ...            ...
# 54226       54226     76597      76583         5000         5000.0
# 54227       54227    142608      74724         5000         5000.0
# 54228       54228    117045      70978         3500         3500.0
# 54229       54229     88854      70699         5000         5000.0
# 54230       54230     72323      70694         5000         5000.0
#
#        funded_amount_inv  term  int_rate  instalment grade  ... recoveries  \
# 0                 8000.0  36.0      7.49      248.82     A  ...       0.00
# 1                13200.0  36.0      6.99      407.52     A  ...       0.00
# 2                16000.0  36.0      7.49      497.63     A  ...       0.00
# 3                15000.0  36.0     14.31      514.93     C  ...       0.00
# 4                15000.0  36.0      6.03      456.54     A  ...       0.00
# ...                  ...   ...       ...         ...   ...  ...        ...
# 54226             1775.0  36.0      9.01      159.03     B  ...       0.00
# 54227             2350.0  36.0     10.59      162.73     C  ...       0.00
# 54228             2225.0  36.0      7.43      108.77     A  ...       0.00
# 54229              225.0  36.0      7.43      155.38     A  ...       0.00
# 54230              350.0  36.0     11.54      164.98     C  ...     182.27
#
#       collection_recovery_fee last_payment_date  last_payment_amount  \
# 0                        0.00          Jan-2022               248.82
# 1                        0.00          Jan-2022               407.52
# 2                        0.00          Oct-2021             12850.16
# 3                        0.00          Jun-2021             13899.67
# 4                        0.00          Jan-2022               456.54
# ...                       ...               ...                  ...
# 54226                    0.00          Jul-2016               160.61
# 54227                    0.00          Oct-2016               490.01
# 54228                    0.00          Sep-2016               110.58
# 54229                    0.00          Mar-2014                 0.00
# 54230                    1.84          Mar-2014               164.97
#
#       next_payment_date last_credit_pull_date collections_12_mths_ex_med  \
# 0              Feb-2022              Jan-2022                        0.0
# 1              Feb-2022              Jan-2022                        0.0
# 2                   NaN              Oct-2021                        0.0
# 3                   NaN              Jun-2021                        0.0
# 4              Feb-2022              Jan-2022                        0.0
# ...                 ...                   ...                        ...
# 54226               NaN              Jul-2016                        NaN
# 54227               NaN              Sep-2016                        0.0
# 54228          Sep-2016              May-2013                        NaN
# 54229               NaN              May-2013                        NaN
# 54230          Dec-2014              Jan-2015                        NaN
#
#       mths_since_last_major_derog policy_code  application_type
# 0                             5.0           1        INDIVIDUAL
# 1                             NaN           1        INDIVIDUAL
# 2                             NaN           1        INDIVIDUAL
# 3                             NaN           1        INDIVIDUAL
# 4                             NaN           1        INDIVIDUAL
# ...                           ...         ...               ...
# 54226                         NaN           1        INDIVIDUAL
# 54227                         NaN           1        INDIVIDUAL
# 54228                         NaN           1        INDIVIDUAL
# 54229                         NaN           1        INDIVIDUAL
# 54230                         NaN           1        INDIVIDUAL
#
# [54231 rows x 44 columns]

# %%
loan_tf.column_to_categorical(['grade', 'sub_grade', 'home_ownership',
                              'verification_status', 'loan_status', 'payment_plan', 'purpose'])
# Out:
#        Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0               0  38676116   41461848         8000         8000.0
# 1               1  38656203   41440010        13200        13200.0
# 2               2  38656154   41439961        16000        16000.0
# 3               3  38656128   41439934        15000        15000.0
# 4               4  38656121   41439927        15000        15000.0
# ...           ...       ...        ...          ...            ...
# 54226       54226     76597      76583         5000         5000.0
# 54227       54227    142608      74724         5000         5000.0
# 54228       54228    117045      70978         3500         3500.0
# 54229       54229     88854      70699         5000         5000.0
# 54230       54230     72323      70694         5000         5000.0
#
#        funded_amount_inv  term  int_rate  instalment grade  ... recoveries  \
# 0                 8000.0  36.0      7.49      248.82     A  ...       0.00
# 1                13200.0  36.0      6.99      407.52     A  ...       0.00
# 2                16000.0  36.0      7.49      497.63     A  ...       0.00
# 3                15000.0  36.0     14.31      514.93     C  ...       0.00
# 4                15000.0  36.0      6.03      456.54     A  ...       0.00
# ...                  ...   ...       ...         ...   ...  ...        ...
# 54226             1775.0  36.0      9.01      159.03     B  ...       0.00
# 54227             2350.0  36.0     10.59      162.73     C  ...       0.00
# 54228             2225.0  36.0      7.43      108.77     A  ...       0.00
# 54229              225.0  36.0      7.43      155.38     A  ...       0.00
# 54230              350.0  36.0     11.54      164.98     C  ...     182.27
#
#       collection_recovery_fee last_payment_date  last_payment_amount  \
# 0                        0.00          Jan-2022               248.82
# 1                        0.00          Jan-2022               407.52
# 2                        0.00          Oct-2021             12850.16
# 3                        0.00          Jun-2021             13899.67
# 4                        0.00          Jan-2022               456.54
# ...                       ...               ...                  ...
# 54226                    0.00          Jul-2016               160.61
# 54227                    0.00          Oct-2016               490.01
# 54228                    0.00          Sep-2016               110.58
# 54229                    0.00          Mar-2014                 0.00
# 54230                    1.84          Mar-2014               164.97
#
#       next_payment_date last_credit_pull_date collections_12_mths_ex_med  \
# 0              Feb-2022              Jan-2022                        0.0
# 1              Feb-2022              Jan-2022                        0.0
# 2                   NaN              Oct-2021                        0.0
# 3                   NaN              Jun-2021                        0.0
# 4              Feb-2022              Jan-2022                        0.0
# ...                 ...                   ...                        ...
# 54226               NaN              Jul-2016                        NaN
# 54227               NaN              Sep-2016                        0.0
# 54228          Sep-2016              May-2013                        NaN
# 54229               NaN              May-2013                        NaN
# 54230          Dec-2014              Jan-2015                        NaN
#
#       mths_since_last_major_derog policy_code  application_type
# 0                             5.0           1        INDIVIDUAL
# 1                             NaN           1        INDIVIDUAL
# 2                             NaN           1        INDIVIDUAL
# 3                             NaN           1        INDIVIDUAL
# 4                             NaN           1        INDIVIDUAL
# ...                           ...         ...               ...
# 54226                         NaN           1        INDIVIDUAL
# 54227                         NaN           1        INDIVIDUAL
# 54228                         NaN           1        INDIVIDUAL
# 54229                         NaN           1        INDIVIDUAL
# 54230                         NaN           1        INDIVIDUAL
#
# [54231 rows x 44 columns]

# %%
# converting object columns to datetime ones
loan_tf.object_to_datetime('issue_date', '%b-%Y')
loan_tf.object_to_datetime('earliest_credit_line', '%b-%Y')
loan_tf.object_to_datetime('last_payment_date', '%b-%Y')
loan_tf.object_to_datetime('next_payment_date', '%b-%Y')
loan_tf.object_to_datetime('last_credit_pull_date', '%b-%Y')
# Out:
#        Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0               0  38676116   41461848         8000         8000.0
# 1               1  38656203   41440010        13200        13200.0
# 2               2  38656154   41439961        16000        16000.0
# 3               3  38656128   41439934        15000        15000.0
# 4               4  38656121   41439927        15000        15000.0
# ...           ...       ...        ...          ...            ...
# 54226       54226     76597      76583         5000         5000.0
# 54227       54227    142608      74724         5000         5000.0
# 54228       54228    117045      70978         3500         3500.0
# 54229       54229     88854      70699         5000         5000.0
# 54230       54230     72323      70694         5000         5000.0
#
#        funded_amount_inv  term  int_rate  instalment grade  ... recoveries  \
# 0                 8000.0  36.0      7.49      248.82     A  ...       0.00
# 1                13200.0  36.0      6.99      407.52     A  ...       0.00
# 2                16000.0  36.0      7.49      497.63     A  ...       0.00
# 3                15000.0  36.0     14.31      514.93     C  ...       0.00
# 4                15000.0  36.0      6.03      456.54     A  ...       0.00
# ...                  ...   ...       ...         ...   ...  ...        ...
# 54226             1775.0  36.0      9.01      159.03     B  ...       0.00
# 54227             2350.0  36.0     10.59      162.73     C  ...       0.00
# 54228             2225.0  36.0      7.43      108.77     A  ...       0.00
# 54229              225.0  36.0      7.43      155.38     A  ...       0.00
# 54230              350.0  36.0     11.54      164.98     C  ...     182.27
#
#       collection_recovery_fee last_payment_date  last_payment_amount  \
# 0                        0.00        2022-01-01               248.82
# 1                        0.00        2022-01-01               407.52
# 2                        0.00        2021-10-01             12850.16
# 3                        0.00        2021-06-01             13899.67
# 4                        0.00        2022-01-01               456.54
# ...                       ...               ...                  ...
# 54226                    0.00        2016-07-01               160.61
# 54227                    0.00        2016-10-01               490.01
# 54228                    0.00        2016-09-01               110.58
# 54229                    0.00        2014-03-01                 0.00
# 54230                    1.84        2014-03-01               164.97
#
#       next_payment_date last_credit_pull_date collections_12_mths_ex_med  \
# 0            2022-02-01            2022-01-01                        0.0
# 1            2022-02-01            2022-01-01                        0.0
# 2                   NaT            2021-10-01                        0.0
# 3                   NaT            2021-06-01                        0.0
# 4            2022-02-01            2022-01-01                        0.0
# ...                 ...                   ...                        ...
# 54226               NaT            2016-07-01                        NaN
# 54227               NaT            2016-09-01                        0.0
# 54228        2016-09-01            2013-05-01                        NaN
# 54229               NaT            2013-05-01                        NaN
# 54230        2014-12-01            2015-01-01                        NaN
#
#       mths_since_last_major_derog policy_code  application_type
# 0                             5.0           1        INDIVIDUAL
# 1                             NaN           1        INDIVIDUAL
# 2                             NaN           1        INDIVIDUAL
# 3                             NaN           1        INDIVIDUAL
# 4                             NaN           1        INDIVIDUAL
# ...                           ...         ...               ...
# 54226                         NaN           1        INDIVIDUAL
# 54227                         NaN           1        INDIVIDUAL
# 54228                         NaN           1        INDIVIDUAL
# 54229                         NaN           1        INDIVIDUAL
# 54230                         NaN           1        INDIVIDUAL
#
# [54231 rows x 44 columns]

# %% [markdown]
# ## Null Values

# %%
# print percentage of NaN values in columns
loan_info.null_values_count()
# Out:
# Unnamed: 0: 0 missing values, 0.0%
# id: 0 missing values, 0.0%
# member_id: 0 missing values, 0.0%
# loan_amount: 0 missing values, 0.0%
# funded_amount: 3007 missing values, 5.54%
# funded_amount_inv: 0 missing values, 0.0%
# term: 4772 missing values, 8.8%
# int_rate: 5169 missing values, 9.53%
# instalment: 0 missing values, 0.0%
# grade: 0 missing values, 0.0%
# sub_grade: 0 missing values, 0.0%
# employment_length: 2118 missing values, 3.91%
# home_ownership: 0 missing values, 0.0%
# annual_inc: 0 missing values, 0.0%
# verification_status: 0 missing values, 0.0%
# issue_date: 0 missing values, 0.0%
# loan_status: 0 missing values, 0.0%
# payment_plan: 0 missing values, 0.0%
# purpose: 0 missing values, 0.0%
# dti: 0 missing values, 0.0%
# delinq_2yrs: 0 missing values, 0.0%
# earliest_credit_line: 0 missing values, 0.0%
# inq_last_6mths: 0 missing values, 0.0%
# mths_since_last_delinq: 31002 missing values, 57.17%
# mths_since_last_record: 48050 missing values, 88.6%
# open_accounts: 0 missing values, 0.0%
# total_accounts: 0 missing values, 0.0%
# out_prncp: 0 missing values, 0.0%
# out_prncp_inv: 0 missing values, 0.0%
# total_payment: 0 missing values, 0.0%
# total_payment_inv: 0 missing values, 0.0%
# total_rec_prncp: 0 missing values, 0.0%
# total_rec_int: 0 missing values, 0.0%
# total_rec_late_fee: 0 missing values, 0.0%
# recoveries: 0 missing values, 0.0%
# collection_recovery_fee: 0 missing values, 0.0%
# last_payment_date: 73 missing values, 0.13%
# last_payment_amount: 0 missing values, 0.0%
# next_payment_date: 32608 missing values, 60.13%
# last_credit_pull_date: 7 missing values, 0.01%
# collections_12_mths_ex_med: 51 missing values, 0.09%
# mths_since_last_major_derog: 46732 missing values, 86.17%
# policy_code: 0 missing values, 0.0%
# application_type: 0 missing values, 0.0%

# %% [markdown]
# ### Dropping columns

# %%
# drop columns with high percentage of missing values
# these columns have 50 - 86 % of missing values which is a high number and
# dropping rows would loose lots of data hence dropping columns will be the right course of action
loan_tf.drop_columns(['mths_since_last_major_derog', 'next_payment_date',
                     'mths_since_last_record', 'mths_since_last_delinq'])

# %%
# Checking null values after dropping
loan_info.null_values_count()
# Out:
# Unnamed: 0: 0 missing values, 0.0%
# id: 0 missing values, 0.0%
# member_id: 0 missing values, 0.0%
# loan_amount: 0 missing values, 0.0%
# funded_amount: 3007 missing values, 5.54%
# funded_amount_inv: 0 missing values, 0.0%
# term: 4772 missing values, 8.8%
# int_rate: 5169 missing values, 9.53%
# instalment: 0 missing values, 0.0%
# grade: 0 missing values, 0.0%
# sub_grade: 0 missing values, 0.0%
# employment_length: 2118 missing values, 3.91%
# home_ownership: 0 missing values, 0.0%
# annual_inc: 0 missing values, 0.0%
# verification_status: 0 missing values, 0.0%
# issue_date: 0 missing values, 0.0%
# loan_status: 0 missing values, 0.0%
# payment_plan: 0 missing values, 0.0%
# purpose: 0 missing values, 0.0%
# dti: 0 missing values, 0.0%
# delinq_2yrs: 0 missing values, 0.0%
# earliest_credit_line: 0 missing values, 0.0%
# inq_last_6mths: 0 missing values, 0.0%
# open_accounts: 0 missing values, 0.0%
# total_accounts: 0 missing values, 0.0%
# out_prncp: 0 missing values, 0.0%
# out_prncp_inv: 0 missing values, 0.0%
# total_payment: 0 missing values, 0.0%
# total_payment_inv: 0 missing values, 0.0%
# total_rec_prncp: 0 missing values, 0.0%
# total_rec_int: 0 missing values, 0.0%
# total_rec_late_fee: 0 missing values, 0.0%
# recoveries: 0 missing values, 0.0%
# collection_recovery_fee: 0 missing values, 0.0%
# last_payment_date: 73 missing values, 0.13%
# last_payment_amount: 0 missing values, 0.0%
# last_credit_pull_date: 7 missing values, 0.01%
# collections_12_mths_ex_med: 51 missing values, 0.09%
# policy_code: 0 missing values, 0.0%
# application_type: 0 missing values, 0.0%

# %% [markdown]
# ### Columns Imputation
# Following columns need to be investigated for imputation:
# 1. funded_amount
# 2. term
# 3. int_rate
# 4. employement_length
# 5. last_payment_date
# 6. last_credit_pull_date
# 7. collections_12_mths_ex_med

# %%
# D'Agostino's K^2 test to find out the p-value
loan_info.dagostino_test('funded_amount')
# Out:
# Statistics = 4491.436, p=0.000

# %%
# p-value close to 0 means data are normally distributed
# still good idea to confirm via data visualisation
# initialise the plotter object
loan_plot = Plotter(loan_df)

# %%
# histogram with 20 bins
loan_plot.histogram('funded_amount', 20)

# %%
# another way is qq_plot to see the distribution
loan_plot.qq_plot('funded_amount')

# %%
# and finally to display mean and median of the column
loan_info.mean('funded_amount')
loan_info.median('funded_amount')
# Out:
# 13229.50911682024
# 12000.0

# %%
# Because the histogram seems to prove that the data are skewed, I will choose median value to impute funded_amount column
loan_tf.data_impute('funded_amount', 'median')
# Out:
#        Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0               0  38676116   41461848         8000         8000.0
# 1               1  38656203   41440010        13200        13200.0
# 2               2  38656154   41439961        16000        16000.0
# 3               3  38656128   41439934        15000        15000.0
# 4               4  38656121   41439927        15000        15000.0
# ...           ...       ...        ...          ...            ...
# 54226       54226     76597      76583         5000         5000.0
# 54227       54227    142608      74724         5000         5000.0
# 54228       54228    117045      70978         3500         3500.0
# 54229       54229     88854      70699         5000         5000.0
# 54230       54230     72323      70694         5000         5000.0
#
#        funded_amount_inv  term  int_rate  instalment grade  ... total_rec_int  \
# 0                 8000.0  36.0      7.49      248.82     A  ...        512.21
# 1                13200.0  36.0      6.99      407.52     A  ...        787.94
# 2                16000.0  36.0      7.49      497.63     A  ...        824.54
# 3                15000.0  36.0     14.31      514.93     C  ...        947.47
# 4                15000.0  36.0      6.03      456.54     A  ...        770.93
# ...                  ...   ...       ...         ...   ...  ...           ...
# 54226             1775.0  36.0      9.01      159.03     B  ...        724.82
# 54227             2350.0  36.0     10.59      162.73     C  ...        826.31
# 54228             2225.0  36.0      7.43      108.77     A  ...        415.37
# 54229              225.0  36.0      7.43      155.38     A  ...        174.18
# 54230              350.0  36.0     11.54      164.98     C  ...        352.34
#
#       total_rec_late_fee recoveries  collection_recovery_fee  \
# 0               0.000000       0.00                     0.00
# 1               0.000000       0.00                     0.00
# 2               0.000000       0.00                     0.00
# 3               0.000000       0.00                     0.00
# 4               0.000000       0.00                     0.00
# ...                  ...        ...                      ...
# 54226           0.000000       0.00                     0.00
# 54227         104.942381       0.00                     0.00
# 54228           0.000000       0.00                     0.00
# 54229           0.000000       0.00                     0.00
# 54230           0.000000     182.27                     1.84
#
#       last_payment_date last_payment_amount last_credit_pull_date  \
# 0            2022-01-01              248.82            2022-01-01
# 1            2022-01-01              407.52            2022-01-01
# 2            2021-10-01            12850.16            2021-10-01
# 3            2021-06-01            13899.67            2021-06-01
# 4            2022-01-01              456.54            2022-01-01
# ...                 ...                 ...                   ...
# 54226        2016-07-01              160.61            2016-07-01
# 54227        2016-10-01              490.01            2016-09-01
# 54228        2016-09-01              110.58            2013-05-01
# 54229        2014-03-01                0.00            2013-05-01
# 54230        2014-03-01              164.97            2015-01-01
#
#       collections_12_mths_ex_med policy_code  application_type
# 0                            0.0           1        INDIVIDUAL
# 1                            0.0           1        INDIVIDUAL
# 2                            0.0           1        INDIVIDUAL
# 3                            0.0           1        INDIVIDUAL
# 4                            0.0           1        INDIVIDUAL
# ...                          ...         ...               ...
# 54226                        NaN           1        INDIVIDUAL
# 54227                        0.0           1        INDIVIDUAL
# 54228                        NaN           1        INDIVIDUAL
# 54229                        NaN           1        INDIVIDUAL
# 54230                        NaN           1        INDIVIDUAL
#
# [54231 rows x 40 columns]

# %% [markdown]
# Similar approach is chosen to investigate all the other numeric columns with missing values

# %%
# term column is hard to impute since there are only two values
# and the decision which one to choose would be a pure guess since
# there are no columns to infer the values from either. Therefore
# a decision to drop the entire column seems to be the best approach
loan_plot.histogram('term', bins=2)

# %%
loan_tf.drop_columns('term')

# %%
# D'Agostino's K^2 test to find out the p-value
loan_info.dagostino_test('int_rate')
# Out:
# Statistics = 1421.934, p=0.000

# %%
# D'Agostino's K^2 test to find out the p-value
loan_info.dagostino_test('collections_12_mths_ex_med')
# Out:
# Statistics = 118894.649, p=0.000

# %%
# histogram with 20 bins
loan_plot.histogram('int_rate', 20)

# %%
loan_plot.qq_plot('int_rate')

# %%
# We can see here that both, mean and median are almost identical
# However, the decision is to impute the missing values with median since the
# histogram shows a skewness of the data 
loan_info.mean('int_rate')
loan_info.median('int_rate')
# Out:
# 13.507328482328484
# 13.16

# %%
loan_tf.data_impute('int_rate', 'median')
# Out:
#        Unnamed: 0        id  member_id  loan_amount  funded_amount  \
# 0               0  38676116   41461848         8000         8000.0
# 1               1  38656203   41440010        13200        13200.0
# 2               2  38656154   41439961        16000        16000.0
# 3               3  38656128   41439934        15000        15000.0
# 4               4  38656121   41439927        15000        15000.0
# ...           ...       ...        ...          ...            ...
# 54226       54226     76597      76583         5000         5000.0
# 54227       54227    142608      74724         5000         5000.0
# 54228       54228    117045      70978         3500         3500.0
# 54229       54229     88854      70699         5000         5000.0
# 54230       54230     72323      70694         5000         5000.0
#
#        funded_amount_inv  int_rate  instalment grade sub_grade  ...  \
# 0                 8000.0      7.49      248.82     A        A4  ...
# 1                13200.0      6.99      407.52     A        A3  ...
# 2                16000.0      7.49      497.63     A        A4  ...
# 3                15000.0     14.31      514.93     C        C4  ...
# 4                15000.0      6.03      456.54     A        A1  ...
# ...                  ...       ...         ...   ...       ...  ...
# 54226             1775.0      9.01      159.03     B        B2  ...
# 54227             2350.0     10.59      162.73     C        C2  ...
# 54228             2225.0      7.43      108.77     A        A2  ...
# 54229              225.0      7.43      155.38     A        A2  ...
# 54230              350.0     11.54      164.98     C        C5  ...
#
#       total_rec_int total_rec_late_fee  recoveries collection_recovery_fee  \
# 0            512.21           0.000000        0.00                    0.00
# 1            787.94           0.000000        0.00                    0.00
# 2            824.54           0.000000        0.00                    0.00
# 3            947.47           0.000000        0.00                    0.00
# 4            770.93           0.000000        0.00                    0.00
# ...             ...                ...         ...                     ...
# 54226        724.82           0.000000        0.00                    0.00
# 54227        826.31         104.942381        0.00                    0.00
# 54228        415.37           0.000000        0.00                    0.00
# 54229        174.18           0.000000        0.00                    0.00
# 54230        352.34           0.000000      182.27                    1.84
#
#       last_payment_date last_payment_amount last_credit_pull_date  \
# 0            2022-01-01              248.82            2022-01-01
# 1            2022-01-01              407.52            2022-01-01
# 2            2021-10-01            12850.16            2021-10-01
# 3            2021-06-01            13899.67            2021-06-01
# 4            2022-01-01              456.54            2022-01-01
# ...                 ...                 ...                   ...
# 54226        2016-07-01              160.61            2016-07-01
# 54227        2016-10-01              490.01            2016-09-01
# 54228        2016-09-01              110.58            2013-05-01
# 54229        2014-03-01                0.00            2013-05-01
# 54230        2014-03-01              164.97            2015-01-01
#
#       collections_12_mths_ex_med  policy_code  application_type
# 0                            0.0            1        INDIVIDUAL
# 1                            0.0            1        INDIVIDUAL
# 2                            0.0            1        INDIVIDUAL
# 3                            0.0            1        INDIVIDUAL
# 4                            0.0            1        INDIVIDUAL
# ...                          ...          ...               ...
# 54226                        NaN            1        INDIVIDUAL
# 54227                        0.0            1        INDIVIDUAL
# 54228                        NaN            1        INDIVIDUAL
# 54229                        NaN            1        INDIVIDUAL
# 54230                        NaN            1        INDIVIDUAL
#
# [54231 rows x 39 columns]

# %%
# employement length exploration
loan_df['employment_length'].value_counts()
# Out:
# employment_length
# 10+ years    15907
# 2 years       5066
# < 1 year      5034
# 3 years       4589
# 5 years       3836
# 1 year        3708
# 4 years       3482
# 6 years       3059
# 7 years       2964
# 8 years       2537
# 9 years       1931
# Name: count, dtype: int64

# %%
loan_df['employment_length'].hist(xrot=90)
# Out:
# <Axes: >

# %%
loan_df['employment_length'].value_counts(dropna=False)
# Out:
# employment_length
# 10+ years    15907
# 2 years       5066
# < 1 year      5034
# 3 years       4589
# 5 years       3836
# 1 year        3708
# 4 years       3482
# 6 years       3059
# 7 years       2964
# 8 years       2537
# NaN           2118
# 9 years       1931
# Name: count, dtype: int64

# %%
mode_value = loan_df['employment_length'].mode().iloc[0]
print("Mode:", mode_value)
# Out:
# Mode: 10+ years

# %%
# majority of the values belongs to 10 + but other than that the distribution
# of the values seems to be normal. Therefore the decision to impute the missing data with mode 
# seems to be a logical approach since we are not dealing with numeric values
# However, it doesn't mean it is the right approach but I'll go with this decision for now
loan_df['employment_length'].fillna(loan_df['employment_length'].mode().iloc[0], inplace=True)

# %%
loan_df['employment_length'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 54231 entries, 0 to 54230
# Series name: employment_length
# Non-Null Count  Dtype
# --------------  -----
# 54231 non-null  object
# dtypes: object(1)
# memory usage: 423.8+ KB

# %%
# Because the last_payment_date, last_pull_date and collections_12_mths_ex_med missing only small percentage of values 
# I've decided not to impute to values but to drop NaN rows since only 73 rows will be lost
loan_df.dropna(subset=['collections_12_mths_ex_med', 'last_payment_date', 'last_credit_pull_date'], inplace=True)

# %%
# check null values again
loan_info.null_values_count()
# Out:
# Unnamed: 0: 0 missing values, 0.0%
# id: 0 missing values, 0.0%
# member_id: 0 missing values, 0.0%
# loan_amount: 0 missing values, 0.0%
# funded_amount: 0 missing values, 0.0%
# funded_amount_inv: 0 missing values, 0.0%
# int_rate: 0 missing values, 0.0%
# instalment: 0 missing values, 0.0%
# grade: 0 missing values, 0.0%
# sub_grade: 0 missing values, 0.0%
# employment_length: 0 missing values, 0.0%
# home_ownership: 0 missing values, 0.0%
# annual_inc: 0 missing values, 0.0%
# verification_status: 0 missing values, 0.0%
# issue_date: 0 missing values, 0.0%
# loan_status: 0 missing values, 0.0%
# payment_plan: 0 missing values, 0.0%
# purpose: 0 missing values, 0.0%
# dti: 0 missing values, 0.0%
# delinq_2yrs: 0 missing values, 0.0%
# earliest_credit_line: 0 missing values, 0.0%
# inq_last_6mths: 0 missing values, 0.0%
# open_accounts: 0 missing values, 0.0%
# total_accounts: 0 missing values, 0.0%
# out_prncp: 0 missing values, 0.0%
# out_prncp_inv: 0 missing values, 0.0%
# total_payment: 0 missing values, 0.0%
# total_payment_inv: 0 missing values, 0.0%
# total_rec_prncp: 0 missing values, 0.0%
# total_rec_int: 0 missing values, 0.0%
# total_rec_late_fee: 0 missing values, 0.0%
# recoveries: 0 missing values, 0.0%
# collection_recovery_fee: 0 missing values, 0.0%
# last_payment_date: 0 missing values, 0.0%
# last_payment_amount: 0 missing values, 0.0%
# last_credit_pull_date: 0 missing values, 0.0%
# collections_12_mths_ex_med: 0 missing values, 0.0%
# policy_code: 0 missing values, 0.0%
# application_type: 0 missing values, 0.0%

# %%
# To see the equal number of rows in the dataset, here's the visualisation bar graph
loan_plot.missing_values_bar()

# %% [markdown]
# ## Skewness

# %% [markdown]
# The best way to represent skewness is through histogram or mathematically using pandas skew method. We'll use only visualisation tools since we have category variables on which the skew method cannot be applied.

# %% [markdown]
# #### Print Skewness for all columns

# %%
print(loan_df.hist(figsize=(20,15)))
# Out:
# [[<Axes: title={'center': 'Unnamed: 0'}> <Axes: title={'center': 'id'}>
#   <Axes: title={'center': 'member_id'}>
#   <Axes: title={'center': 'loan_amount'}>
#   <Axes: title={'center': 'funded_amount'}>]
#  [<Axes: title={'center': 'funded_amount_inv'}>
#   <Axes: title={'center': 'int_rate'}>
#   <Axes: title={'center': 'instalment'}>
#   <Axes: title={'center': 'annual_inc'}>
#   <Axes: title={'center': 'issue_date'}>]
#  [<Axes: title={'center': 'dti'}> <Axes: title={'center': 'delinq_2yrs'}>
#   <Axes: title={'center': 'earliest_credit_line'}>
#   <Axes: title={'center': 'inq_last_6mths'}>
#   <Axes: title={'center': 'open_accounts'}>]
#  [<Axes: title={'center': 'total_accounts'}>
#   <Axes: title={'center': 'out_prncp'}>
#   <Axes: title={'center': 'out_prncp_inv'}>
#   <Axes: title={'center': 'total_payment'}>
#   <Axes: title={'center': 'total_payment_inv'}>]
#  [<Axes: title={'center': 'total_rec_prncp'}>
#   <Axes: title={'center': 'total_rec_int'}>
#   <Axes: title={'center': 'total_rec_late_fee'}>
#   <Axes: title={'center': 'recoveries'}>
#   <Axes: title={'center': 'collection_recovery_fee'}>]
#  [<Axes: title={'center': 'last_payment_date'}>
#   <Axes: title={'center': 'last_payment_amount'}>
#   <Axes: title={'center': 'last_credit_pull_date'}>
#   <Axes: title={'center': 'collections_12_mths_ex_med'}>
#   <Axes: title={'center': 'policy_code'}>]]

# %% [markdown]
# #### Positive skews

# %% [markdown]
# From the histograms we can conclude that the following variables have positive skew:
# 1. loan_amount
# 2. funded_amount
# 3. funded_amount_inv
# 4. instalment
# 5. open_accounts
# 6. total accounts
# 7. out_prncp
# 8. out_prncp_inv
# 9. total_payment
# 10. total_payment_inv
# 11. total_rec_prncp
# 12. total_rec_int
# 13. last_payment_amount

# %% [markdown]
# Because all these values are numerical, let's try to confirm the assumptions using pandas skew method

# %%
loan_df[['loan_amount', 'funded_amount', 'funded_amount_inv', 'instalment', 'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'total_rec_int', 'last_payment_amount']].skew()
# Out:
# loan_amount            0.804312
# funded_amount          0.869102
# funded_amount_inv      0.814251
# instalment             0.996150
# open_accounts          1.059493
# total_accounts         0.780083
# out_prncp              2.352526
# out_prncp_inv          2.352946
# total_payment          1.269266
# total_payment_inv      1.258474
# total_rec_prncp        1.262007
# total_rec_int          2.203625
# last_payment_amount    2.496079
# dtype: float64

# %% [markdown]
# ***All columns above have values above 0.5 which suggest they are moderetaly and some highly skewed!***

# %% [markdown]
# #### Negative skews

# %% [markdown]
# The following columns suggest negative skewness from the histograms:
# 1. issue_date
# 2. earliest_credit_line
# 3. last_payment_date
# 4. last_credit_pull_date

# %% [markdown]
# ***All these columns are of datetime data type and therefore I have decided not to normalise/transform the values of these values.***

# %% [markdown]
# **Let's try Yeo_Johnson transform for resolving positive skewness identified earlier. The reason for choosing it is that some of the variables have negative values and Box-Cox works only for positive values**

# %%
loan_tf.yj_transform('loan_amount')
loan_tf.yj_transform('funded_amount')
loan_tf.yj_transform('funded_amount_inv')
loan_tf.yj_transform('instalment')
loan_tf.yj_transform('open_accounts')
loan_tf.yj_transform('total_accounts')
loan_tf.yj_transform('out_prncp')
loan_tf.yj_transform('out_prncp_inv')
loan_tf.yj_transform('total_payment')
loan_tf.yj_transform('total_payment_inv')
loan_tf.yj_transform('total_rec_prncp')
loan_tf.yj_transform('total_rec_int')
loan_tf.yj_transform('last_payment_amount')

# %%
# let's print the histogram of the transformed variables again
loan_df[['loan_amount', 'funded_amount', 'funded_amount_inv', 'instalment',
         'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 
        'total_payment', 'total_payment_inv', 'total_rec_prncp',
        'total_rec_int', 'last_payment_amount']].hist(figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'loan_amount'}>,
#         <Axes: title={'center': 'funded_amount'}>,
#         <Axes: title={'center': 'funded_amount_inv'}>,
#         <Axes: title={'center': 'instalment'}>],
#        [<Axes: title={'center': 'open_accounts'}>,
#         <Axes: title={'center': 'total_accounts'}>,
#         <Axes: title={'center': 'out_prncp'}>,
#         <Axes: title={'center': 'out_prncp_inv'}>],
#        [<Axes: title={'center': 'total_payment'}>,
#         <Axes: title={'center': 'total_payment_inv'}>,
#         <Axes: title={'center': 'total_rec_prncp'}>,
#         <Axes: title={'center': 'total_rec_int'}>],
#        [<Axes: title={'center': 'last_payment_amount'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
# and have a look at skew too
loan_df[['loan_amount', 'funded_amount', 'funded_amount_inv', 'instalment',
         'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 
        'total_payment', 'total_payment_inv', 'total_rec_prncp',
        'total_rec_int', 'last_payment_amount']].skew()
# Out:
# loan_amount           -0.042782
# funded_amount         -0.029736
# funded_amount_inv     -0.035047
# instalment            -0.020439
# open_accounts          0.001399
# total_accounts        -0.012742
# out_prncp              0.528308
# out_prncp_inv          0.528326
# total_payment         -0.014033
# total_payment_inv      0.005727
# total_rec_prncp       -0.017952
# total_rec_int          0.001459
# last_payment_amount    0.002584
# dtype: float64

# %% [markdown]
# **All the values are now near zero apart from out_prncp and out_prncp_inv. However, their skew value is much less than it was so for now I'll leave it as it is.**

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Visualise outliers
# There are many ways how to visualise outliers but for me the easier way to identify outliers is to visualise them through a boxplot. At this stage I will not consider to visualise datetime columns as I believe any dates data might be important which was the reason for not imputing any missing dates. Deciding what to do with the dates would depend on the analysis requirements and goal.

# %%
# name of columns to identify outliers
columns = ['loan_amount', 'funded_amount', 'funded_amount_inv', 'int_rate', 'instalment', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 'open_accounts', 'total_accounts', 'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv', 'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries', 'collection_recovery_fee','last_payment_amount', 'collections_12_mths_ex_med', 'policy_code']
len(columns)
# Out:
# 23

# %%
loan_plot.boxplot(columns, 23)

# %% [markdown]
# **Dealing with outliers has to be considerate since we can loose a valuable information. For example, boxplot showing that annual_income column has lots of outliers. But these outliers may be genuine values since comanies with 2 mil. income can have loan as well. Therefore I have only identified 3 numeric columns at this stage worth investigating further**

# %%
# looking at the top range values
loan_df['total_rec_late_fee'].sort_values(ascending=False).head(5)
# Out:
# 21963    358.680000
# 20089    229.750000
# 29590    178.800000
# 48333    166.429711
# 8346     145.200000
# Name: total_rec_late_fee, dtype: float64

# %%
# At this stage because I don't have any more information I'll remove the the highest value
# which could be a possible error since the difference is quite substantial and could cause 
# problems during i.e. machine learning modeling
loan_df = loan_df[loan_df['total_rec_late_fee'] != 358.68]

# %%
loan_df['total_rec_late_fee'].sort_values(ascending=False).head(5)
# Out:
# 20089    229.750000
# 29590    178.800000
# 48333    166.429711
# 8346     145.200000
# 52181    143.093045
# Name: total_rec_late_fee, dtype: float64

# %%
# I do not have sufficient information whether here the highest value is an error and I would personally 
# remove the value only in next iteration after more information and therefore at this stage
# I will leave the recoveries column unchanged
loan_df['recoveries'].sort_values(ascending=False).head(5)
# Out:
# 54148    27750.00
# 29077    23035.92
# 34909    22943.37
# 44587    20006.53
# 49785    19915.67
# Name: recoveries, dtype: float64

# %%
# The same approach as with the recoveries columns
loan_df['collections_12_mths_ex_med'].sort_values(ascending=False).head(5)
# Out:
# 11537    4.0
# 1809     3.0
# 3840     2.0
# 31636    2.0
# 17635    2.0
# Name: collections_12_mths_ex_med, dtype: float64

# %% [markdown]
# **As mentioned previously dealing with outliers without further analysis requirements is difficult and removing values without additional information or investigation and therefore I've decided to action only on one columne**

# %%
# let's have a look at total_rec_late_fee boxplot after removing the maximum value identified as an otlier and possible error
# first initialise loan_plot again with the updated dataframe
loan_plot = Plotter(loan_df)
loan_plot.boxplot('total_rec_late_fee')

# %% [markdown]
# ## Colinearity

# %%
import plotly.express as px

# %%
# first, let's get numeric columns only
numeric_columns = loan_df.select_dtypes(include=['number'])

# see the correlation heatmap
px.imshow(numeric_columns.corr(), title="Correlation heatmap of student dataframe")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/eda_project/lib/python3.11/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/envs/eda_project/lib/python3.11/site-packages/plotly/basedatatypes.py:842, in BaseFigure._ipython_display_(self)
#     839 import plotly.io as pio
#     841 if pio.renderers.render_on_display and pio.renderers.default:
# --> 842     pio.show(self)
#     843 else:
#     844     print(repr(self))
#
# File ~/anaconda3/envs/eda_project/lib/python3.11/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or LooseVersion(nbformat.__version__) < LooseVersion("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'x: %{x}<br>y: %{y}<br>color: %{z}<extra></extra>',
#               'name': '0',
#               'type': 'heatmap',
#               'x': array(['Unnamed: 0', 'id', 'member_id', 'loan_amount', 'funded_amount',
#                           'funded_amount_inv', 'int_rate', 'instalment', 'annual_inc', 'dti',
#                           'delinq_2yrs', 'inq_last_6mths', 'open_accounts', 'total_accounts',
#                           'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv',
#                           'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#                           'collection_recovery_fee', 'last_payment_amount',
#                           'collections_12_mths_ex_med', 'policy_code'], dtype=object),
#               'xaxis': 'x',
#               'y': array(['Unnamed: 0', 'id', 'member_id', 'loan_amount', 'funded_amount',
#                           'funded_amount_inv', 'int_rate', 'instalment', 'annual_inc', 'dti',
#                           'delinq_2yrs', 'inq_last_6mths', 'open_accounts', 'total_accounts',
#                           'out_prncp', 'out_prncp_inv', 'total_payment', 'total_payment_inv',
#                           'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#                           'collection_recovery_fee', 'last_payment_amount',
#                           'collections_12_mths_ex_med', 'policy_code'], dtype=object),
#               'yaxis': 'y',
#               'z': array([[ 1.00000000e+00, -7.40848970e-01, -7.71352212e-01, ...,
#                            -7.41961205e-02, -5.67918393e-02,             nan],
#                           [-7.40848970e-01,  1.00000000e+00,  9.94187824e-01, ...,
#                            -2.29226984e-02,  7.43513362e-02,             nan],
#                           [-7.71352212e-01,  9.94187824e-01,  1.00000000e+00, ...,
#                            -1.85253987e-02,  7.25650888e-02,             nan],
#                           ...,
#                           [-7.41961205e-02, -2.29226984e-02, -1.85253987e-02, ...,
#                             1.00000000e+00,  1.94401206e-04,             nan],
#                           [-5.67918393e-02,  7.43513362e-02,  7.25650888e-02, ...,
#                             1.94401206e-04,  1.00000000e+00,             nan],
#                           [            nan,             nan,             nan, ...,
#                                        nan,             nan,             nan]])}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'template': '...',
#                'title': {'text': 'Correlation heatmap of student dataframe'},
#                'xaxis': {'anchor': 'y', 'constrain': 'domain', 'domain': [0.0, 1.0], 'scaleanchor': 'y'},
#                'yaxis': {'anchor': 'x', 'autorange': 'reversed', 'constrain': 'domain', 'domain': [0.0, 1.0]}}
# })

# %%
pd.set_option('display.max_columns', None)
# see the correlation matrix
numeric_columns.corr()
# Out:
#                             Unnamed: 0        id  member_id  loan_amount  \
# Unnamed: 0                    1.000000 -0.740849  -0.771352    -0.212380
# id                           -0.740849  1.000000   0.994188     0.134837
# member_id                    -0.771352  0.994188   1.000000     0.141675
# loan_amount                  -0.212380  0.134837   0.141675     1.000000
# funded_amount                -0.220363  0.139642   0.146858     0.966499
# funded_amount_inv            -0.291331  0.174063   0.182984     0.957057
# int_rate                     -0.151448  0.055997   0.060477     0.059494
# instalment                   -0.237000  0.145057   0.153068     0.963760
# annual_inc                   -0.046395  0.042262   0.041998     0.024063
# dti                          -0.247430  0.200429   0.202795     0.050943
# delinq_2yrs                  -0.085821  0.063769   0.064122     0.020369
# inq_last_6mths                0.136608 -0.093056  -0.097234    -0.038622
# open_accounts                -0.197326  0.152877   0.155663     0.242321
# total_accounts               -0.149715  0.106253   0.107854     0.275453
# out_prncp                    -0.517336  0.443001   0.455455     0.187328
# out_prncp_inv                -0.517365  0.443028   0.455482     0.187311
# total_payment                 0.026549 -0.177773  -0.170771     0.819651
# total_payment_inv            -0.047630 -0.135024  -0.126414     0.797421
# total_rec_prncp               0.073440 -0.202734  -0.197520     0.687472
# total_rec_int                -0.103921 -0.029028  -0.020689     0.768810
# total_rec_late_fee            0.078200 -0.051810  -0.053791    -0.022590
# recoveries                    0.011029 -0.029975  -0.029896     0.008800
# collection_recovery_fee       0.020554 -0.020579  -0.021294     0.002751
# last_payment_amount          -0.074196 -0.022923  -0.018525     0.379531
# collections_12_mths_ex_med   -0.056792  0.074351   0.072565     0.007067
# policy_code                        NaN       NaN        NaN          NaN
#
#                             funded_amount  funded_amount_inv  int_rate  \
# Unnamed: 0                      -0.220363          -0.291331 -0.151448
# id                               0.139642           0.174063  0.055997
# member_id                        0.146858           0.182984  0.060477
# loan_amount                      0.966499           0.957057  0.059494
# funded_amount                    1.000000           0.936254  0.061563
# funded_amount_inv                0.936254           1.000000  0.075041
# int_rate                         0.061563           0.075041  1.000000
# instalment                       0.941623           0.930690  0.073230
# annual_inc                       0.024527           0.029332  0.003453
# dti                              0.053327           0.070831  0.171843
# delinq_2yrs                      0.022818           0.022179  0.107813
# inq_last_6mths                  -0.040301          -0.076664  0.163804
# open_accounts                    0.236273           0.241522  0.048821
# total_accounts                   0.267367           0.274337  0.034403
# out_prncp                        0.190031           0.222993  0.100597
# out_prncp_inv                    0.190026           0.223005  0.100611
# total_payment                    0.796575           0.786514  0.042164
# total_payment_inv                0.777738           0.837109  0.053983
# total_rec_prncp                  0.667182           0.654728  0.022271
# total_rec_int                    0.749797           0.748004  0.072396
# total_rec_late_fee              -0.021001          -0.037241  0.046434
# recoveries                       0.008021           0.007447  0.111382
# collection_recovery_fee          0.002715          -0.002360  0.058711
# last_payment_amount              0.369490           0.374402  0.038350
# collections_12_mths_ex_med       0.007377           0.010270  0.032762
# policy_code                           NaN                NaN       NaN
#
#                             instalment  annual_inc       dti  delinq_2yrs  \
# Unnamed: 0                   -0.237000   -0.046395 -0.247430    -0.085821
# id                            0.145057    0.042262  0.200429     0.063769
# member_id                     0.153068    0.041998  0.202795     0.064122
# loan_amount                   0.963760    0.024063  0.050943     0.020369
# funded_amount                 0.941623    0.024527  0.053327     0.022818
# funded_amount_inv             0.930690    0.029332  0.070831     0.022179
# int_rate                      0.073230    0.003453  0.171843     0.107813
# instalment                    1.000000    0.024995  0.058634     0.022985
# annual_inc                    0.024995    1.000000 -0.162841     0.055623
# dti                           0.058634   -0.162841  1.000000     0.007809
# delinq_2yrs                   0.022985    0.055623  0.007809     1.000000
# inq_last_6mths               -0.034612    0.049017 -0.018497     0.008541
# open_accounts                 0.242224    0.005262  0.072158     0.017222
# total_accounts                0.259011    0.006677  0.054710     0.016494
# out_prncp                     0.176349    0.029758  0.147095     0.054648
# out_prncp_inv                 0.176343    0.029758  0.147095     0.054654
# total_payment                 0.818584    0.008993 -0.012870    -0.001179
# total_payment_inv             0.794568    0.013448  0.005356     0.000521
# total_rec_prncp               0.709702    0.005495 -0.028231    -0.006997
# total_rec_int                 0.723313    0.013402  0.029773     0.013012
# total_rec_late_fee           -0.021537    0.012790 -0.022496     0.021329
# recoveries                    0.007302    0.025014  0.016903     0.010042
# collection_recovery_fee       0.001932    0.019934  0.003520     0.009198
# last_payment_amount           0.386334    0.004557  0.017847    -0.000608
# collections_12_mths_ex_med    0.008367    0.006239  0.012075     0.026361
# policy_code                        NaN         NaN       NaN          NaN
#
#                             inq_last_6mths  open_accounts  total_accounts  \
# Unnamed: 0                        0.136608      -0.197326       -0.149715
# id                               -0.093056       0.152877        0.106253
# member_id                        -0.097234       0.155663        0.107854
# loan_amount                      -0.038622       0.242321        0.275453
# funded_amount                    -0.040301       0.236273        0.267367
# funded_amount_inv                -0.076664       0.241522        0.274337
# int_rate                          0.163804       0.048821        0.034403
# instalment                       -0.034612       0.242224        0.259011
# annual_inc                        0.049017       0.005262        0.006677
# dti                              -0.018497       0.072158        0.054710
# delinq_2yrs                       0.008541       0.017222        0.016494
# inq_last_6mths                    1.000000      -0.025908       -0.025900
# open_accounts                    -0.025908       1.000000        0.705337
# total_accounts                   -0.025900       0.705337        1.000000
# out_prncp                        -0.079489       0.132276        0.066404
# out_prncp_inv                    -0.079485       0.132274        0.066394
# total_payment                    -0.011761       0.167483        0.214112
# total_payment_inv                -0.047741       0.169867        0.218652
# total_rec_prncp                  -0.004349       0.139806        0.194507
# total_rec_int                    -0.022855       0.165103        0.153639
# total_rec_late_fee                0.053032      -0.015441       -0.012390
# recoveries                        0.044632      -0.007135       -0.004684
# collection_recovery_fee           0.038735      -0.007418       -0.005556
# last_payment_amount              -0.019906       0.094617        0.153959
# collections_12_mths_ex_med       -0.006315       0.020745        0.009262
# policy_code                            NaN            NaN             NaN
#
#                             out_prncp  out_prncp_inv  total_payment  \
# Unnamed: 0                  -0.517336      -0.517365       0.026549
# id                           0.443001       0.443028      -0.177773
# member_id                    0.455455       0.455482      -0.170771
# loan_amount                  0.187328       0.187311       0.819651
# funded_amount                0.190031       0.190026       0.796575
# funded_amount_inv            0.222993       0.223005       0.786514
# int_rate                     0.100597       0.100611       0.042164
# instalment                   0.176349       0.176343       0.818584
# annual_inc                   0.029758       0.029758       0.008993
# dti                          0.147095       0.147095      -0.012870
# delinq_2yrs                  0.054648       0.054654      -0.001179
# inq_last_6mths              -0.079489      -0.079485      -0.011761
# open_accounts                0.132276       0.132274       0.167483
# total_accounts               0.066404       0.066394       0.214112
# out_prncp                    1.000000       0.999999      -0.051608
# out_prncp_inv                0.999999       1.000000      -0.051640
# total_payment               -0.051608      -0.051640       1.000000
# total_payment_inv           -0.019271      -0.019274       0.963153
# total_rec_prncp             -0.153518      -0.153547       0.954752
# total_rec_int                0.324057       0.324032       0.723306
# total_rec_late_fee          -0.043423      -0.043423      -0.006977
# recoveries                  -0.007039      -0.007038       0.016423
# collection_recovery_fee     -0.010913      -0.010912       0.006926
# last_payment_amount         -0.361095      -0.361096       0.539763
# collections_12_mths_ex_med   0.032426       0.032428      -0.011863
# policy_code                       NaN            NaN            NaN
#
#                             total_payment_inv  total_rec_prncp  total_rec_int  \
# Unnamed: 0                          -0.047630         0.073440      -0.103921
# id                                  -0.135024        -0.202734      -0.029028
# member_id                           -0.126414        -0.197520      -0.020689
# loan_amount                          0.797421         0.687472       0.768810
# funded_amount                        0.777738         0.667182       0.749797
# funded_amount_inv                    0.837109         0.654728       0.748004
# int_rate                             0.053983         0.022271       0.072396
# instalment                           0.794568         0.709702       0.723313
# annual_inc                           0.013448         0.005495       0.013402
# dti                                  0.005356        -0.028231       0.029773
# delinq_2yrs                          0.000521        -0.006997       0.013012
# inq_last_6mths                      -0.047741        -0.004349      -0.022855
# open_accounts                        0.169867         0.139806       0.165103
# total_accounts                       0.218652         0.194507       0.153639
# out_prncp                           -0.019271        -0.153518       0.324057
# out_prncp_inv                       -0.019274        -0.153547       0.324032
# total_payment                        0.963153         0.954752       0.723306
# total_payment_inv                    1.000000         0.915526       0.705025
# total_rec_prncp                      0.915526         1.000000       0.529034
# total_rec_int                        0.705025         0.529034       1.000000
# total_rec_late_fee                  -0.021501        -0.002343      -0.011997
# recoveries                           0.015956         0.013352       0.014159
# collection_recovery_fee              0.002994         0.005243       0.005762
# last_payment_amount                  0.533158         0.594470       0.134891
# collections_12_mths_ex_med          -0.008535        -0.013261      -0.002457
# policy_code                               NaN              NaN            NaN
#
#                             total_rec_late_fee  recoveries  \
# Unnamed: 0                            0.078200    0.011029
# id                                   -0.051810   -0.029975
# member_id                            -0.053791   -0.029896
# loan_amount                          -0.022590    0.008800
# funded_amount                        -0.021001    0.008021
# funded_amount_inv                    -0.037241    0.007447
# int_rate                              0.046434    0.111382
# instalment                           -0.021537    0.007302
# annual_inc                            0.012790    0.025014
# dti                                  -0.022496    0.016903
# delinq_2yrs                           0.021329    0.010042
# inq_last_6mths                        0.053032    0.044632
# open_accounts                        -0.015441   -0.007135
# total_accounts                       -0.012390   -0.004684
# out_prncp                            -0.043423   -0.007039
# out_prncp_inv                        -0.043423   -0.007038
# total_payment                        -0.006977    0.016423
# total_payment_inv                    -0.021501    0.015956
# total_rec_prncp                      -0.002343    0.013352
# total_rec_int                        -0.011997    0.014159
# total_rec_late_fee                    1.000000    0.094287
# recoveries                            0.094287    1.000000
# collection_recovery_fee               0.098898    0.814028
# last_payment_amount                  -0.016295    0.006470
# collections_12_mths_ex_med           -0.002643   -0.002130
# policy_code                                NaN         NaN
#
#                             collection_recovery_fee  last_payment_amount  \
# Unnamed: 0                                 0.020554            -0.074196
# id                                        -0.020579            -0.022923
# member_id                                 -0.021294            -0.018525
# loan_amount                                0.002751             0.379531
# funded_amount                              0.002715             0.369490
# funded_amount_inv                         -0.002360             0.374402
# int_rate                                   0.058711             0.038350
# instalment                                 0.001932             0.386334
# annual_inc                                 0.019934             0.004557
# dti                                        0.003520             0.017847
# delinq_2yrs                                0.009198            -0.000608
# inq_last_6mths                             0.038735            -0.019906
# open_accounts                             -0.007418             0.094617
# total_accounts                            -0.005556             0.153959
# out_prncp                                 -0.010913            -0.361095
# out_prncp_inv                             -0.010912            -0.361096
# total_payment                              0.006926             0.539763
# total_payment_inv                          0.002994             0.533158
# total_rec_prncp                            0.005243             0.594470
# total_rec_int                              0.005762             0.134891
# total_rec_late_fee                         0.098898            -0.016295
# recoveries                                 0.814028             0.006470
# collection_recovery_fee                    1.000000            -0.001711
# last_payment_amount                       -0.001711             1.000000
# collections_12_mths_ex_med                -0.001516             0.000194
# policy_code                                     NaN                  NaN
#
#                             collections_12_mths_ex_med  policy_code
# Unnamed: 0                                   -0.056792          NaN
# id                                            0.074351          NaN
# member_id                                     0.072565          NaN
# loan_amount                                   0.007067          NaN
# funded_amount                                 0.007377          NaN
# funded_amount_inv                             0.010270          NaN
# int_rate                                      0.032762          NaN
# instalment                                    0.008367          NaN
# annual_inc                                    0.006239          NaN
# dti                                           0.012075          NaN
# delinq_2yrs                                   0.026361          NaN
# inq_last_6mths                               -0.006315          NaN
# open_accounts                                 0.020745          NaN
# total_accounts                                0.009262          NaN
# out_prncp                                     0.032426          NaN
# out_prncp_inv                                 0.032428          NaN
# total_payment                                -0.011863          NaN
# total_payment_inv                            -0.008535          NaN
# total_rec_prncp                              -0.013261          NaN
# total_rec_int                                -0.002457          NaN
# total_rec_late_fee                           -0.002643          NaN
# recoveries                                   -0.002130          NaN
# collection_recovery_fee                      -0.001516          NaN
# last_payment_amount                           0.000194          NaN
# collections_12_mths_ex_med                    1.000000          NaN
# policy_code                                        NaN          NaN

# %% [markdown]
# The above table proves the following strong correlations:
# 1. total_payment and total_payment_inv with total_rec_prncp
# 2. loan_amount, funded_amount, funded_amount_inv with installment
# 3. funded_amount, funded_amount_inv with loan_amount
# 4. member_id with id
#
# There are also strong correlations between payments and amounts and inv columns but that is expected since inv columns are proportional to their appropriate columns.
# Every column that has a correlation with other column above 0.90 or -0.90 has been considered as strong correlation and therefore the following columns will be dropped from the dataset:
# 1. id
# 2. total_rec_prncp
# Installment is expected to be strongly correlated with the loan_amount and funded_amount and would not consider it at this stage as an issue and the same applies to the loan_amount and funded_amount correlation. Strong correlation in such cases can somtimes be helpful in prediction of a third variable.

# %%
loan_df = loan_df.drop(['id', 'total_rec_prncp'], axis=1)
